# %% [markdown]
# # Reto 5:
#
# ---

# %% [markdown]
# ## Ejercicio 1: Funciones

# %% [markdown]
# De nuestro código que evaluaba cual era una el número mayor, convertirla a función.
#
# Entrada: num1, num2
#
# Salida:
#
# 1. El num1 es mayor que num2
# 2. El num2 es mayor que num2
# 3. Ambos son iguales

# %%
def numMayor(num1, num2):
    if num1<num2:
        print("el número 2 es mayor al número 1")
    elif num1> num2:   
        print("el número 1 es mayor al número 2")
    else:
        print("Son iguales")
numMayor(4,5)
# Out:
# el número 2 es mayor al número 1

# %%
x=int(input("num1"))
y=int(input("num2"))

numMayor(x, y)
# Out:
# el número 2 es mayor al número 1

# %% [markdown]
# ## Ejercicio 2:

# %% [markdown]
# Crear una función que reciba como parameto un texto y que devuelva en el `return` una lista que contenga cada palabra del texto.
#
# |Entrada | Salida |
# | - | - |
# | "El señor de los anillos" | ["El", "señor", "de", "los", "anillos"] |
#
#
#
# Utiliar el metodo .split() al texto
#
# **Ejemplo**
#
# "Buenos días".split()

# %%
def Palabras(lista):
    lista.split
    return lista

# %%
lista=("Buenos días".split())
print (lista)
# Out:
# ['Buenos', 'días']

# %%
def split_text(texto):
    text="El señor de los anillos"
    split_text(text)    
    return texto.split()

# %% [markdown]
# ## Ejercicio 3:

# %% [markdown]
# Un piloto de carreras ha registrado su velocidad cada segundo en la siguiente lista:
#
# velocidad = [0, 60, 80, 117, 140, 155, 170, 189, 205, 223, 234, 239, 234, 227, 215, 180, 155, 160, 189, 206, 235]
#
# Hacer una función que imprima en que segundo el piloto rebaso los 210 km/h
#
#
# **Ejemplo de impresión**
#
# En el segundo `9` el piloto llego a los `223` km/h

# %%
def limite_velocidad(velocidades):
    segundos = 0

    for velocidad in velocidades:
        if velocidad> 210:
            print(f"En el segundo {segundos} el piloto {velocidad}")
            segundos= segundos + 1

# %%
x = [0, 60, 80, 117, 140, 155, 170, 189, 205, 223, 234, 239, 234, 227, 215, 180, 155, 160, 189, 206, 235]

limite_velocidad(x)
# Out:
# En el segundo 0 el piloto 223
# En el segundo 1 el piloto 234
# En el segundo 2 el piloto 239
# En el segundo 3 el piloto 234
# En el segundo 4 el piloto 227
# En el segundo 5 el piloto 215
# En el segundo 6 el piloto 235

# %% [markdown]
# ## Extra points

# %% [markdown]
# Hacer una función que nos imprima cuantos números pares e impares tiene una lista.
#
# Para evaluar un par o impar puedes utilizar el
#
# ```Python
# if numero%2 = 0:
#     print("numero es par")
# else:
#     print("numero es impar")
# ```
#
# |Entrada | Salida |
# | - | - |
# | [2,3,6,8,9] | Tiene `3` pares y `2` inpares |

# %%
def numeros_paresEimpares(una_lista):
    contador_par= 0
    contador_impar= 0

    for numero in una_lista:
        if numero%2 == 0:
            contador_par += 1
        else:
            contador_impar += 1
    return f'Tiene {contador_par} pares y {contador_impar} impares'

# %%
numeros={2,3,6,8,9}

numeros_paresEimpares(numeros)
# Out:
# 'Tiene 3 pares y 2 impares'
